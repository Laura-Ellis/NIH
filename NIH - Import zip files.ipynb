# %% [markdown]
# This script is to import and combine zip files from NIH Reporter. Data downloaded 2024/09/28.

# %%
# Setup
import os
import zipfile
import pandas as pd
import numpy as np

# Set the current working directory
os.chdir(r'D:\\NIH\\2024')

# %%
# Assistant
# List of directories to process (folders containing zip files)
directories = ['projects', 'abstracts', 'publinks', 'pubs']

# Initialize dictionaries to hold DataFrames for each category
dataframes = {directory: pd.DataFrame() for directory in directories}

# Function to unzip files and read CSVs
def process_directory(directory):
    # Create a path for the directory
    dir_path = os.path.join(os.getcwd(), directory)
    
    # Unzip all ZIP files in the directory
    for item in os.listdir(dir_path):
        if item.endswith('.zip'):
            zip_path = os.path.join(dir_path, item)
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                zip_ref.extractall(dir_path)  # Extract to the same directory
                print(f'Extracted: {zip_path}')
    
    # Read all CSV files in the directory and combine them into a single DataFrame
    for filename in os.listdir(dir_path):
        if filename.endswith('.csv'):
            csv_path = os.path.join(dir_path, filename)
            # Specify encoding to handle potential UnicodeDecodeError
            df = pd.read_csv(csv_path, encoding='latin1')  # Changed encoding here
            dataframes[directory] = pd.concat([dataframes[directory], df], ignore_index=True)
            print(f'Combined CSV: {csv_path}')

# Process each directory
for directory in directories:
    process_directory(directory)

# Now you have one DataFrame for each directory
projects_df = dataframes['projects']
abstracts_df = dataframes['abstracts']
publinks_df = dataframes['publinks']
pubs_df = dataframes['pubs']

# Example: Display the first few rows of each DataFrame
print("Projects DataFrame:")
print(projects_df.head())
print("\nAbstracts DataFrame:")
print(abstracts_df.head())
print("\nPublish Links DataFrame:")
print(publinks_df.head())
print("\nPublications DataFrame:")
print(pubs_df.head())
# Out:
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2023.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2018.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2020.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2019.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2021.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2022.zip
# Extracted: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2017.zip
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2023.csv
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2018.csv
# C:\Users\Laura\AppData\Local\Temp\ipykernel_1352\2559562781.py:26: DtypeWarning: Columns (17,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='latin1')  # Changed encoding here
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2020.csv
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2019.csv
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2021.csv
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2022.csv
# Combined CSV: D:\NIH\2024\projects\RePORTER_PRJ_C_FY2017.csv
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2018.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2019.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2023.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2020.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2021.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2022.zip
# Extracted: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2017.zip
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2018_new.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2019_new.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2023.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2020_new.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2021.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2022.csv
# Combined CSV: D:\NIH\2024\abstracts\RePORTER_PRJABS_C_FY2017_new.csv
# Extracted: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2019.zip
# Extracted: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2020.zip
# Extracted: D:\NIH\2024\publinks\RePORTER_PRJABS_C_FY2017.zip
# Extracted: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2021.zip
# Extracted: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2022.zip
# Extracted: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2023.zip
# Combined CSV: D:\NIH\2024\publinks\REPORTER_PUBLNK_C_2019.csv
# Combined CSV: D:\NIH\2024\publinks\REPORTER_PUBLNK_C_2020.csv
# Combined CSV: D:\NIH\2024\publinks\RePORTER_PRJABS_C_FY2017_new.csv
# Combined CSV: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_2021.csv
# Combined CSV: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2022.csv
# Combined CSV: D:\NIH\2024\publinks\RePORTER_PUBLNK_C_FY2023.csv
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2019.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2020.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2021.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2022.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2023.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2018.zip
# Extracted: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2017.zip
# Combined CSV: D:\NIH\2024\pubs\REPORTER_PUB_C_2019.csv
# Combined CSV: D:\NIH\2024\pubs\REPORTER_PUB_C_2020.csv
# Combined CSV: D:\NIH\2024\pubs\RePORTER_PUB_C_2021.csv
# Combined CSV: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2022.csv
# Combined CSV: D:\NIH\2024\pubs\RePORTER_PUB_C_FY2023.csv
# Combined CSV: D:\NIH\2024\pubs\REPORTER_PUB_C_2018.csv
# Combined CSV: D:\NIH\2024\pubs\REPORTER_PUB_C_2017.csv
# Projects DataFrame:
#    APPLICATION_ID ACTIVITY ADMINISTERING_IC  APPLICATION_TYPE ARRA_FUNDED  \
# 0         8530931      I50               VA               1.0           N
# 1         9075408      I50               VA               5.0           N
# 2         9701510      R01               DK               7.0           N
# 3         9722309      R01               MH               5.0           N
# 4        10003845      R01               FD               5.0           N
#
#   AWARD_NOTICE_DATE BUDGET_START  BUDGET_END  CFDA_CODE CORE_PROJECT_NUM  ...  \
# 0        2023-08-28   2012-10-01  2013-09-30      999.0      I50HX001175  ...
# 1        2023-09-06   2015-10-01  2016-09-30      999.0      I50HX001676  ...
# 2        2023-04-18   2023-01-01  2024-12-31      847.0      R01DK056123  ...
# 3        2023-05-16   2023-05-01  2024-04-30      242.0      R01MH115504  ...
# 4        2023-08-29   2023-09-01  2024-08-31      103.0      R01FD006106  ...
#
#   SERIAL_NUMBER STUDY_SECTION  \
# 0        1175.0           HQ4
# 1        1676.0           HQ4
# 2       56123.0           MCE
# 3      115504.0          ZRG1
# 4        6106.0          ZFD1
#
#                                   STUDY_SECTION_NAME SUBPROJECT_ID SUFFIX  \
# 0                  HQ4 QUERI RRP Review Panel 3[HQ4]           NaN    NaN
# 1                  HQ4 QUERI RRP Review Panel 3[HQ4]           NaN    NaN
# 2  Molecular and Cellular Endocrinology Study Sec...           NaN    NaN
# 3            Special Emphasis Panel[ZRG1-BDA-A(50)R]           NaN    NaN
# 4                                       ZFD1-SRC(99)           NaN    NaN
#
#    SUPPORT_YEAR DIRECT_COST_AMT INDIRECT_COST_AMT TOTAL_COST  \
# 0           1.0             NaN               NaN        NaN
# 1           2.0             NaN               NaN        NaN
# 2          22.0        406000.0          263900.0   669900.0
# 3           3.0        442857.0            6237.0   449094.0
# 4           3.0        339012.0          128763.0   467775.0
#
#   TOTAL_COST_SUB_PROJECT
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 46 columns]
#
# Abstracts DataFrame:
#    APPLICATION_ID                                      ABSTRACT_TEXT
# 0         9773850  The In Vitro and Animal Models for Emerging Di...
# 1         9773851  The In Vitro and Animal Models for Emerging Di...
# 2         9741524  The NICHD's Contraceptive Clinical Trials netw...
# 3         9486057  Project Summary / Abstract  The ubiquitin-prot...
# 4         9485709  PROJECT SUMMARY Protein-protein and protein-nu...
#
# Publish Links DataFrame:
#          PMID PROJECT_NUMBER  APPLICATION_ID ABSTRACT_TEXT
# 0  26902887.0    P30CA016672             NaN           NaN
# 1  26902887.0    R01CA092579             NaN           NaN
# 2  27155985.0    K23MH092696             NaN           NaN
# 3  27155985.0    KL2TR002015             NaN           NaN
# 4  27112505.0    T32HD043021             NaN           NaN
#
# Publications DataFrame:
#                                          AFFILIATION  \
# 0  From the VA Ann Arbor Center for Clinical Mana...
# 1  The Children's Hospital of Philadelphia, PA, U...
# 2  Department of Computer Science, University of ...
# 3    a Department of Psychology , Temple University.
# 4                     1 Clemson University, SC, USA.
#
#                                          AUTHOR_LIST        COUNTRY  \
# 0  Krein, Sarah L; Kuhn, Latoya; Ratz, David; Cho...  United States
# 1  Culyba, Alison J; Ginsburg, Kenneth R; Fein, J...  United States
# 2  Ruan, Jianhua; Jahid, Md Jamiul; Gu, Fei; Lei,...  United States
# 3  Peterman, Jeremy S; Carper, Matthew M; Kendall...        England
# 4  Sianko, Natallia; Hedge, Jasmine M; McDonell, ...  United States
#
#         ISSN JOURNAL_ISSUE                                      JOURNAL_TITLE  \
# 0  1549-8425             4                          Journal of patient safety
# 1  1552-6518             5                  Journal of interpersonal violence
# 2  1089-8646             1                                           Genomics
# 3  1537-4424          sup1  Journal of clinical child and adolescent psych...
# 4  1552-6518             4                  Journal of interpersonal violence
#
#              JOURNAL_TITLE_ABBR JOURNAL_VOLUME LANG PAGE_NUMBER     PMC_ID  \
# 0                 J Patient Saf             15  eng     293-295        NaN
# 1          J Interpers Violence             34  eng   1074-1088  5077680.0
# 2                      Genomics            111  eng       17-23  5253120.0
# 3  J Clin Child Adolesc Psychol             48  eng     S34-S44  5199625.0
# 4          J Interpers Violence             34  eng     712-740  5154777.0
#
#        PMID    PUB_DATE                                          PUB_TITLE  \
# 0  26558650     2019 12  Use of Designated Nurse PICC Teams and CLABSI ...
# 1  27112505  2019 03 01  Examining the Role of Supportive Family Connec...
# 2  27453286     2019 01  A novel algorithm for network-based prediction...
# 3  27355694        2019  Testing the Habituation-Based Model of Exposur...
# 4  27106255     2019 02  Differential Adjustment Among Rural Adolescent...
#
#    PUB_YEAR ï»¿"AFFILIATION"
# 0      2019              NaN
# 1      2019              NaN
# 2      2019              NaN
# 3      2019              NaN
# 4      2019              NaN

# %%
# Export each DataFrame to a separate CSV file
projects_df.to_csv('projects_data.csv', index=False)
abstracts_df.to_csv('abstracts_data.csv', index=False)
publinks_df.to_csv('publinks_data.csv', index=False)
pubs_df.to_csv('pubs_data.csv', index=False)

print("DataFrames exported to CSV files:")
print("- projects_data.csv")
print("- abstracts_data.csv")
print("- publinks_data.csv")
print("- pubs_data.csv")
# Out:
# DataFrames exported to CSV files:
# - projects_data.csv
# - abstracts_data.csv
# - publinks_data.csv
# - pubs_data.csv

# %%
import os
import zipfile
import pandas as pd

# Set the current working directory
os.chdir(r'D:\NIH\2024')

# List of directories to process
directories = ['projects', 'abstracts', 'publinks', 'pubs']

# Initialize dictionaries to hold DataFrames for each category
dataframes = {directory: pd.DataFrame() for directory in directories}

# Function to unzip files and read CSVs
def process_directory(directory):
    dir_path = os.path.join(os.getcwd(), directory)
    
    # Unzip all ZIP files in the directory
    for item in os.listdir(dir_path):
        if item.endswith('.zip'):
            zip_path = os.path.join(dir_path, item)
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                zip_ref.extractall(dir_path)  # Extract to the same directory
                print(f'Extracted: {zip_path}')
    
    # Read all CSV files in the directory and combine them into a single DataFrame
    for filename in os.listdir(dir_path):
        if filename.endswith('.csv'):
            csv_path = os.path.join(dir_path, filename)
            df = pd.read_csv(csv_path)
            dataframes[directory] = pd.concat([dataframes[directory], df], ignore_index=True)
            print(f'Combined CSV: {csv_path}')

# Process each directory
for directory in directories:
    process_directory(directory)

# Now you have one DataFrame for each directory
projects_df = dataframes['projects']
abstracts_df = dataframes['abstracts']
publinks_df = dataframes['publinks']
pubs_df = dataframes['pubs']

# Export each DataFrame to a separate CSV file
projects_df.to_csv('projects_data.csv', index=False)
abstracts_df.to_csv('abstracts_data.csv', index=False)
publinks_df.to_csv('publinks_data.csv', index=False)
pubs_df.to_csv('pubs_data.csv', index=False)

print("DataFrames exported to CSV files:")
print("- projects_data.csv")
print("- abstracts_data.csv")
print("- publinks_data.csv")
print("- pubs_data.csv")

# Create a DataFrame to hold the DataFrame names and their column names
data_info = {
    'DataFrame Name': [],
    'Column Names': []
}

# Populate the data_info dictionary
for name, df in zip(['Projects', 'Abstracts', 'Publish Links', 'Publications'], 
                    [projects_df, abstracts_df, publinks_df, pubs_df]):
    data_info['DataFrame Name'].append(name)
    data_info['Column Names'].append(', '.join(df.columns))

# Convert to DataFrame
info_df = pd.DataFrame(data_info)

# Export the DataFrame to an Excel file
info_df.to_excel('directory.xlsx', index=False)

print("DataFrame information exported to directory.xlsx")

# %%
# Create a DataFrame to hold the DataFrame names and their column names
data_info = {
    'DataFrame Name': [],
    'Column Names': []
}

# Populate the data_info dictionary
for name, df in zip(['Projects', 'Abstracts', 'Publish Links', 'Publications'], 
                    [projects_df, abstracts_df, publinks_df, pubs_df]):
    for column in df.columns:
        data_info['DataFrame Name'].append(name)
        data_info['Column Names'].append(column)

# Convert to DataFrame
info_df = pd.DataFrame(data_info)

# Export the DataFrame to an Excel file
info_df.to_excel('directory.xlsx', index=False)

print("DataFrame information exported to directory.xlsx")
# Out:
# DataFrame information exported to directory.xlsx
